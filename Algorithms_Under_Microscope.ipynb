# %% [markdown]
# <a href="https://colab.research.google.com/github/kimunilaz/Algorithms_Under_Microscope/blob/main/Algorithms_Under_Microscope.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# **Insertion Sort Algorithm  and Implementation**
# *   Start with the second element as the first element is assumed to be sorted.
#
# *   Compare the second element with the first if the second is smaller then swap them.
#
#
# *   Move to the third element, compare it with the first two, and put it in its correct position
# *   Repeat until the entire array is sorted.
#
#
#
# The following implementation is using python and numpy library
#
# l will user timer to record the runtime of each algorithm and also generate big lists for better visualization of runtime.
#
# l am measuring runtime in seconds.

# %%
import time

#lists to accumulate average runtime for graph plotting
nlogn = []
n_squared = []
n_squared_sorted = []

#sorting function

def insertion_sort(lists):


  for i in range(1, len(lists)):
    n = i - 1
    const = lists[i]


    while n >= 0 and const < lists[n]:
      lists[n + 1] = lists[n]
      n -= 1
    lists[n+1] = const
  return lists

# %% [markdown]
# **Quick Sort Algorithm and Implementation**
#
# 1. Choose a Pivot: Select an element from the array as the pivot. The choice of
# pivot can vary (e.g., first element, last element, random element, or median).
#
# 2. Partition the Array: Re arrange the array around the pivot. After partitioning, all elements smaller than the pivot will be on its left, and all elements greater than the pivot will be on its right.
#
# 3. Recursively Call: Recursively apply the same process to the two partitioned sub-arrays.
# Base Case: The recursion stops when there is only one element left in the sub-array, as a single element is already sorted.:

# %%
#quick sort function

def quicksort(lists):

  if len(lists) <= 1:
    return lists

  small = []
  large = []

  pivot = lists[len(lists) -1 ]

  for i in range(len(lists) - 1):
    if lists[i] < pivot:
      small.append(lists[i])
    else:
      large.append(lists[i])

  sorted_small = quicksort(small)
  sorted_large = quicksort(large)

  return (sorted_small + [pivot] + sorted_large)

# %% [markdown]
# **Both algorithms tested and worked, now l will get test data for the measurements of run time.**
#
#
#
# *   l will use seed to generate same list through all five loops
#
#
#
# **Insertion Sort perfomance on 500 size list**
#
# i will pass a sorted list to the insertion sort as well

# %%
from typing_extensions import runtime_checkable

import random

random.seed(32) # to make it generate same list



total_time = 0

for i in range (5):
  lists = [random.randint(1, 500) for _ in range(500)]


  start = time.perf_counter()
  sorted_list = insertion_sort(lists)
  end = time.perf_counter()

  runtime = end - start
  total_time += runtime
  print("Runtime:", runtime, "seconds")

print(sorted_list[:20]) # to confirm sorting
average_runtime = total_time * 0.2

n_squared.append(average_runtime)

print("Average runtime:", average_runtime )


# using a sorted list
print("USING ALREADY SORTED LIST")


total_time = 0
for i in range (5):

  start = time.perf_counter()
  insertion_sort(sorted_list)
  end = time.perf_counter()

  runtime = end - start
  total_time += runtime
  print("Runtime:", end - start, "seconds")

print(lists[:20]) # to confirm sorting
average_runtime = total_time * 0.2

n_squared_sorted.append(average_runtime)

print("Average runtime:", average_runtime )
# Out:
# Runtime: 0.00735292900026252 seconds
# Runtime: 0.009192627001539222 seconds
# Runtime: 0.007022599000265473 seconds
# Runtime: 0.007436601999870618 seconds
# Runtime: 0.006570558000021265 seconds
# [1, 2, 4, 5, 6, 8, 10, 10, 12, 12, 13, 17, 19, 20, 21, 23, 23, 24, 25, 25]
# Average runtime: 0.00751506300039182
# USING ALREADY SORTED LIST
# Runtime: 5.826800042996183e-05 seconds
# Runtime: 6.198799928824883e-05 seconds
# Runtime: 5.3572999604512006e-05 seconds
# Runtime: 5.322399920260068e-05 seconds
# Runtime: 5.3164001656114124e-05 seconds
# [1, 2, 4, 5, 6, 8, 10, 10, 12, 12, 13, 17, 19, 20, 21, 23, 23, 24, 25, 25]
# Average runtime: 5.6043400036287494e-05

# %% [markdown]
# .
#
#
#
#
# **Quick Sort perfomance on 500 size list**

# %%
total_time = 0
for i in range (5):
  lists = [random.randint(1, 500) for _ in range(500)]


  start = time.perf_counter()
  sorted_list = quicksort(lists)
  end = time.perf_counter()

  runtime = end - start
  total_time += runtime
  print("Runtime:", end - start, "seconds")

print(sorted_list[:20])
average_runtime = total_time * 0.2
nlogn.append(average_runtime)

print("Average runtime:", average_runtime )
# Out:
# Runtime: 0.0005826300002809148 seconds
# Runtime: 0.0005255340001895092 seconds
# Runtime: 0.0008007510004972573 seconds
# Runtime: 0.0005563859995163511 seconds
# Runtime: 0.0005236970009718789 seconds
# [1, 2, 3, 3, 3, 6, 7, 8, 9, 9, 10, 12, 13, 14, 14, 16, 16, 16, 17, 17]
# Average runtime: 0.0005977996002911823

# %% [markdown]
# **Insertion Sort perfomance on 1000 size list**

# %%
total_time = 0

for i in range (5):
  lists = [random.randint(1, 1000) for _ in range(1000)]


  start = time.perf_counter()
  sorted_list = insertion_sort(lists)
  end = time.perf_counter()

  runtime = end - start
  total_time += runtime
  print("Runtime:", end - start, "seconds")

print(sorted_list[:20])
average_runtime = total_time * 0.2

n_squared.append(average_runtime)

print("Average runtime:", average_runtime )


# using a sorted list
print("USING ALREADY SORTED LIST")

total_time = 0
for i in range (5):

  start = time.perf_counter()
  insertion_sort(sorted_list)
  end = time.perf_counter()

  runtime = end - start
  total_time += runtime
  print("Runtime:", end - start, "seconds")

print(sorted_list[:20]) # to confirm sorting
average_runtime = total_time * 0.2

n_squared_sorted.append(average_runtime)

print("Average runtime:", average_runtime )
# Out:
# Runtime: 0.03015146599864238 seconds
# Runtime: 0.0299447159995907 seconds
# Runtime: 0.034489216001020395 seconds
# Runtime: 0.03777518899914867 seconds
# Runtime: 0.030205842000214034 seconds
# [1, 2, 3, 4, 4, 5, 5, 5, 5, 8, 8, 9, 10, 10, 11, 11, 11, 11, 12, 13]
# Average runtime: 0.032513285799723235
# USING ALREADY SORTED LIST
# Runtime: 0.00013294999916979577 seconds
# Runtime: 0.00011795600039476994 seconds
# Runtime: 0.00011971599997195881 seconds
# Runtime: 0.00011695400098687969 seconds
# Runtime: 0.00011645899940049276 seconds
# [1, 2, 3, 4, 4, 5, 5, 5, 5, 8, 8, 9, 10, 10, 11, 11, 11, 11, 12, 13]
# Average runtime: 0.0001208069999847794

# %% [markdown]
# **Quick Sort perfomance on 1000 size list**

# %%
total_time = 0
for i in range (5):
  lists = [random.randint(1, 500) for _ in range(500)]


  start = time.perf_counter()
  sorted_list = quicksort(lists)
  end = time.perf_counter()

  runtime = end - start
  total_time += runtime
  print("Runtime:", end - start, "seconds")

print(sorted_list[:20])
average_runtime = total_time * 0.2
nlogn.append(average_runtime)

print("Average runtime:", average_runtime )
# Out:
# Runtime: 0.0006281569985731039 seconds
# Runtime: 0.0009334429996670224 seconds
# Runtime: 0.000772036999478587 seconds
# Runtime: 0.0005756660011684289 seconds
# Runtime: 0.0005989330002194038 seconds
# [1, 4, 4, 5, 5, 8, 10, 10, 10, 12, 13, 15, 16, 18, 18, 20, 23, 24, 25, 28]
# Average runtime: 0.0007016471998213093

# %% [markdown]
# **Insertion Sort perfomance on 2000 size list**

# %%
total_time = 0

for i in range (5):
  lists = [random.randint(1, 2000) for _ in range(2000)]


  start = time.perf_counter()
  sorted_list = insertion_sort(lists)
  end = time.perf_counter()

  runtime = end - start
  total_time += runtime
  print("Runtime:", end - start, "seconds")

print(lists[:20])
average_runtime = total_time * 0.2

n_squared.append(average_runtime)

print("Average runtime:", average_runtime )


# using a sorted list
print("USING ALREADY SORTED LIST")

total_time = 0
for i in range (5):

  start = time.perf_counter()
  insertion_sort(sorted_list)
  end = time.perf_counter()

  runtime = end - start
  total_time += runtime
  print("Runtime:", end - start, "seconds")

print(sorted_list[:20]) # to confirm sorting
average_runtime = total_time * 0.2

n_squared_sorted.append(average_runtime)

print("Average runtime:", average_runtime )
# Out:
# Runtime: 0.12392966399966099 seconds
# Runtime: 0.1362653460000729 seconds
# Runtime: 0.12876178199985588 seconds
# Runtime: 0.11995876199944178 seconds
# Runtime: 0.12435153899969009 seconds
# [1, 2, 4, 5, 5, 7, 10, 13, 17, 17, 18, 19, 19, 20, 22, 23, 23, 23, 23, 26]
# Average runtime: 0.12665341859974433
# USING ALREADY SORTED LIST
# Runtime: 0.000257412000792101 seconds
# Runtime: 0.00024150799981725868 seconds
# Runtime: 0.00025140300022030715 seconds
# Runtime: 0.00027191399931325577 seconds
# Runtime: 0.00024261299950012472 seconds
# [1, 2, 4, 5, 5, 7, 10, 13, 17, 17, 18, 19, 19, 20, 22, 23, 23, 23, 23, 26]
# Average runtime: 0.0002529699999286095

# %% [markdown]
# **Quick Sort perfomance on 2000 size list**

# %%
total_time = 0
for i in range (5):
  lists = [random.randint(1, 2000) for _ in range(2000)]


  start = time.perf_counter()
  sorted_list = quicksort(lists)
  end = time.perf_counter()

  runtime = end - start
  total_time += runtime
  print("Runtime:", end - start, "seconds")

print(sorted_list[:20])
average_runtime = total_time * 0.2
nlogn.append(average_runtime)

print("Average runtime:", average_runtime )
# Out:
# Runtime: 0.003753556999072316 seconds
# Runtime: 0.003969405999669107 seconds
# Runtime: 0.0031512459991063224 seconds
# Runtime: 0.002582477000032668 seconds
# Runtime: 0.002694451999559533 seconds
# [1, 1, 2, 2, 4, 5, 6, 7, 9, 11, 12, 13, 14, 14, 15, 16, 16, 17, 17, 17]
# Average runtime: 0.003230227599487989

# %% [markdown]
# **Insertion Sort perfomance on 4000 size list**

# %%
total_time = 0

for i in range (5):
  lists = [random.randint(1, 4000) for _ in range(4000)]


  start = time.perf_counter()
  sorted_list = insertion_sort(lists)
  end = time.perf_counter()

  runtime = end - start
  total_time += runtime
  print("Runtime:", end - start, "seconds")

print(sorted_list[:20])
average_runtime = total_time * 0.2

n_squared.append(average_runtime)

print("Average runtime:", average_runtime )


# using a sorted list
print("USING ALREADY SORTED LIST")

total_time = 0
for i in range (5):

  start = time.perf_counter()
  insertion_sort(sorted_list)
  end = time.perf_counter()

  runtime = end - start
  total_time += runtime
  print("Runtime:", end - start, "seconds")

print(sorted_list[:20]) # to confirm sorting
average_runtime = total_time * 0.2

n_squared_sorted.append(average_runtime)

print("Average runtime:", average_runtime )
# Out:
# Runtime: 0.501405788001648 seconds
# Runtime: 0.49737372799972945 seconds
# Runtime: 0.4943559719995392 seconds
# Runtime: 0.4968847910004115 seconds
# Runtime: 0.4942480659992725 seconds
# [1, 1, 2, 2, 2, 2, 3, 4, 5, 7, 7, 8, 8, 10, 10, 11, 11, 12, 12, 13]
# Average runtime: 0.4968536690001202
# USING ALREADY SORTED LIST
# Runtime: 0.0005961690003459807 seconds
# Runtime: 0.0005140770008438267 seconds
# Runtime: 0.0005030600004829466 seconds
# Runtime: 0.0007193630008259788 seconds
# Runtime: 0.0005574110000452492 seconds
# [1, 1, 2, 2, 2, 2, 3, 4, 5, 7, 7, 8, 8, 10, 10, 11, 11, 12, 12, 13]
# Average runtime: 0.0005780160005087964

# %% [markdown]
# **Quick Sort perfomance on 4000 size list**

# %%
total_time = 0
for i in range (5):
  lists = [random.randint(1, 4000) for _ in range(4000)]


  start = time.perf_counter()
  sorted_list = quicksort(lists)
  end = time.perf_counter()

  runtime = end - start
  total_time += runtime
  print("Runtime:", end - start, "seconds")

print(sorted_list[:20])
average_runtime = total_time * 0.2
nlogn.append(average_runtime)

print("Average runtime:", average_runtime )
# Out:
# Runtime: 0.006472418001067126 seconds
# Runtime: 0.008138973000313854 seconds
# Runtime: 0.006059957000616123 seconds
# Runtime: 0.006185766000271542 seconds
# Runtime: 0.007022820998827228 seconds
# [2, 4, 5, 5, 7, 8, 9, 9, 11, 14, 15, 15, 16, 16, 16, 19, 20, 20, 21, 23]
# Average runtime: 0.006775987000219175

# %% [markdown]
# **Insertion Sort perfomance on 8000 size list**

# %%
total_time = 0

for i in range (5):
  lists = [random.randint(1, 8000) for _ in range(8000)]


  start = time.perf_counter()
  sorted_list = insertion_sort(lists)
  end = time.perf_counter()

  runtime = end - start
  total_time += runtime
  print("Runtime:", end - start, "seconds")

print(sorted_list[:20])
average_runtime = total_time * 0.2

n_squared.append(average_runtime)

print("Average runtime:", average_runtime )


# using a sorted list
print("USING ALREADY SORTED LIST")


total_time = 0
for i in range (5):

  start = time.perf_counter()
  insertion_sort(sorted_list)
  end = time.perf_counter()

  runtime = end - start
  total_time += runtime
  print("Runtime:", end - start, "seconds")

print(sorted_list[:20]) # to confirm sorting
average_runtime = total_time * 0.2

n_squared_sorted.append(average_runtime)

print("Average runtime:", average_runtime )
# Out:
# Runtime: 3.0522365190008713 seconds
# Runtime: 2.2894734519995836 seconds
# Runtime: 1.9952635600002395 seconds
# Runtime: 2.0008411920007347 seconds
# Runtime: 1.9791155820003041 seconds
# [4, 8, 8, 8, 8, 9, 9, 9, 11, 11, 11, 12, 13, 13, 14, 15, 16, 17, 17, 17]
# Average runtime: 2.2633860610003467
# USING ALREADY SORTED LIST
# Runtime: 0.0020017509996250737 seconds
# Runtime: 0.0020547870008158498 seconds
# Runtime: 0.0023086979999789037 seconds
# Runtime: 0.0019057099998462945 seconds
# Runtime: 0.0019131789995299187 seconds
# [4, 8, 8, 8, 8, 9, 9, 9, 11, 11, 11, 12, 13, 13, 14, 15, 16, 17, 17, 17]
# Average runtime: 0.0020368249999592083

# %% [markdown]
# **Quick Sort perfomance on 8000 size list**

# %%
total_time = 0
for i in range (5):
  lists = [random.randint(1, 8000) for _ in range(8000)]


  start = time.perf_counter()
  sorted_list = quicksort(lists)
  end = time.perf_counter()

  runtime = end - start
  total_time += runtime
  print("Runtime:", end - start, "seconds")

print(sorted_list[:20])

average_runtime = total_time * 0.2
nlogn.append(average_runtime)

print("Average runtime:", average_runtime )
# Out:
# Runtime: 0.01353349300006812 seconds
# Runtime: 0.013173658000596333 seconds
# Runtime: 0.014301274000899866 seconds
# Runtime: 0.013252232000013464 seconds
# Runtime: 0.014289747001384967 seconds
# [1, 1, 2, 5, 6, 6, 6, 6, 7, 7, 8, 10, 11, 11, 14, 15, 21, 22, 23, 25]
# Average runtime: 0.01371008080059255

# %%
print("n_squared runtime",n_squared)
print( "sorted runtime",n_squared_sorted)
print("nlogn runtime",nlogn)
# Out:
# n_squared runtime [0.00751506300039182, 0.032513285799723235, 0.12665341859974433, 0.4968536690001202, 2.2633860610003467]
# sorted runtime [5.6043400036287494e-05, 0.0001208069999847794, 0.0002529699999286095, 0.0005780160005087964, 0.0020368249999592083]
# nlogn runtime [0.0005977996002911823, 0.0007016471998213093, 0.003230227599487989, 0.006775987000219175, 0.01371008080059255]

# %% [markdown]
# **Predictions**
#
#
#
# *   Insertion sort, random input: time should roughly quadruple when n doubles (O(n²)).
#
# *   Quicksort, random input: time should roughly double when n doubles, with a small extra factor from the log term (O(n log n)).
#
# *   Insertion sort, already-sorted input: should be far faster than on random input, the inner loop never has to shift elements, so it behaves close to O(n).
#
#
#  **Measured Results**
#
#  Each value is the mean of 5 runs, timing only the sort call itself.
#  ![table.png](data:image/png;base64,...)

# %% [markdown]
# **Plotting using Matplotlib**
#
#  One chart: n along the horizontal axis, time in seconds up the vertical, with
# three curves on it:
# 1. O(n²) sort on random input,
# 2. O(n log n) sort on random input,
# 3. O(n²) sort on already-sorted input.
#
#
# *   x-axes list_size
# *   y-axis time(seconds)

# %%
import matplotlib.pyplot as plt

n = [500, 1000, 2000, 4000, 8000]

plt.plot(n, n_squared, marker="o",
         label="O(n²) - Random Input")

plt.plot(n, nlogn, marker="o",
         label="O(n log n) - Random Input")

plt.plot(n, n_squared_sorted, marker="o",
         label="O(n²) - Sorted Input")

plt.xlabel("Input Size, n (number of elements)")
plt.ylabel("Runtime (seconds)")
plt.title("Sorting Algorithm Runtime Comparison")

plt.legend()
plt.grid()

plt.show()

# %% [markdown]
# **Changing the scale to visualize O(nlogn) and O(n_squared) with sorted input**

# %%
n = [500, 1000, 2000, 4000, 8000]

plt.plot(n, n_squared, marker="o",
         label="O(n²) - Random Input")

plt.plot(n, nlogn, marker="o",
         label="O(n log n) - Random Input")

plt.plot(n, n_squared_sorted, marker="o",
         label="O(n²) - Sorted Input")

plt.xlabel("Input Size, n (number of elements)")
plt.ylabel("Runtime (seconds)")
plt.title("Sorting Algorithm Runtime Comparison")



plt.legend()
plt.grid()

plt.ylim(0, 0.05)

plt.show()

# %% [markdown]
# **Doubling Test: Prediction vs. Measurement**
#
#
#
#
#
#
# ![image.png](data:image/png;base64,...)
#
#
#
#
# **Discussion**
#
# **Insertion sort, random input**
#
# Ratios cluster around 4 (3–4.5), matching O(n²). Some noise is expected, wall-clock timing is more affected by system jitter at smaller n, where each run only takes milliseconds.
#
#
#
# **Insertion sort, already-sorted input**
#
# Ratios cluster near 2 (aside from one blip at n=1000→2000, likely noise since those runs took under a millisecond). A ratio near 2 means linear growth, not quadratic. This is the most interesting result: insertion sort's inner while loop shifts elements only when they're out of order. On sorted input nothing is ever out of order, so each element costs one comparison instead of up to i comparisons, the algorithm degrades from its O(n²) worst case down to O(n) on this input.
#
#
# **Quicksort, random input**
#
# Ratios settle around 2 from n=2000 onward, matching O(n log n). The first ratio (0.77, i.e. n=1000 ran faster than n=500) isn't real sub-linear behavior, both runs took under 1.3 ms, where interpreter and system overhead dominate the actual sorting work.
#
#
#
#
# **Assumptions and Limitations**
#
# *  Run on Google Colab's free tier CPU, so some timing noise (e.g. the 0.77 and 1.17 ratios)  might be reflecting system load, not algorithm behavior.
#
# *  Each input list was generated with a fixed random seed, so all sizes and both algorithms were tested on the same reproducible data.
#
# *  Quicksort's pivot was always the last element, not random, on already-sorted or reverse-sorted input this degrades to O(n²), a case not covered here since only insertion sort was tested on sorted input.
#
# *  Inputs were random integers only; other data types or distributions (e.g. many duplicates) may behave differently.
#
# *  Absolute times reflect Python's interpreter overhead: only the growth rates (doubling ratios) are meant to be compared against theory.
#
#
#
#
#
# **Conclusion**
#
# The theory holds: insertion sort roughly quadruples with n (O(n²)), quicksort roughly doubles (O(n log n)), and insertion sort on sorted input drops to linear growth because its inner loop does no work when nothing needs shifting, the one case where its O(n²) label doesn't describe what actually happens.
# In practice, quicksort is the better default: the O(n log n) vs O(n²) gap is already about 170× at n=8000 and only grows from there. Insertion sort is worth choosing only for small n or data that's already nearly sorted.

# %% [markdown]
# ***The End***
