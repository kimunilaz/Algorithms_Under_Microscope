# %% [markdown]
# <a href="https://colab.research.google.com/github/kimunilaz/Algorithms_Under_Microscope/blob/main/Algorithms_Under_Microscope.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# **Insertion Sort Algorithm  and Implementation**
# *   Start with the second element as the first element is assumed to be sorted.
#
# *   Compare the second element with the first if the second is smaller then swap them.
#
#
# *   Move to the third element, compare it with the first two, and put it in its correct position
# *   Repeat until the entire array is sorted.
#
#
#
# The following implementation is using python and numpy library
#
# l will user timer to record the runtime of each algorithm and also generate big lists for better visualization of runtime.
#
# l am measuring runtime in seconds.

# %%
import time

lists = [6,4,3,6,7,8,3,5,7]
# print(lists[n-1])

#start = time.perf_counter()
def insertion_sort(lists):


  for i in range(1, len(lists)):
    n = i - 1
    const = lists[i]


    while n >= 0 and const < lists[n]:
      lists[n + 1] = lists[n]
      n -= 1
    lists[n+1] = const



#insertion_sort(lists)

#end = time.perf_counter()

#print("Runtime:", end - start, "seconds")

# %% [markdown]
# **Quick Sort Algorithm and Implementation**
#
# 1. Choose a Pivot: Select an element from the array as the pivot. The choice of
# pivot can vary (e.g., first element, last element, random element, or median).
#
# 2. Partition the Array: Re arrange the array around the pivot. After partitioning, all elements smaller than the pivot will be on its left, and all elements greater than the pivot will be on its right.
#
# 3. Recursively Call: Recursively apply the same process to the two partitioned sub-arrays.
# Base Case: The recursion stops when there is only one element left in the sub-array, as a single element is already sorted.:

# %%
lists =[6,4,3,7,8,4,6,8,2,8,9]
#lists = np.random.randint(0, 1_000, size=1_000)

print(lists)



start = time.perf_counter()
def quicksort(lists):

  if len(lists) <= 1:
    return lists

  small = []
  large = []

  pivot = lists[len(lists) - 1]

  for i in range(len(lists) - 1):
    if lists[i] < pivot:
      small.append(lists[i])
    else:
      large.append(lists[i])

  sorted_small = quicksort(small)
  sorted_large = quicksort(large)

  return (sorted_small + [pivot] + sorted_large)



end = time.perf_counter()

print("Runtime:", end - start, "seconds")
# Out:
# [6, 4, 3, 7, 8, 4, 6, 8, 2, 8, 9]
# Runtime: 0.0005952539977442939 seconds

# %% [markdown]
# **Both algorithms tested and worked, now l will get test data for the measurements of run time.**
#
#
#
# *   l will use seed to generate same list through all five loops
#
#
#
# **Insertion Sort perfomance on 500 size list**

# %%
import random

random.seed(32) # to make it generate same list



total_time = 0

for i in range (5):
  lists = [random.randint(1, 500) for _ in range(500)]


  start = time.perf_counter()
  insertion_sort(lists)
  end = time.perf_counter()

  runtime = end - start
  total_time += runtime
  print("Runtime:", end - start, "seconds")

print(lists[:20])
print("Average runtime:", total_time * 0.2)
# Out:
# Runtime: 0.008330087999638636 seconds
# Runtime: 0.007054769001115346 seconds
# Runtime: 0.006387123001331929 seconds
# Runtime: 0.006538099998579128 seconds
# Runtime: 0.006083389998821076 seconds
# [1, 2, 4, 5, 6, 8, 10, 10, 12, 12, 13, 17, 19, 20, 21, 23, 23, 24, 25, 25]
# Average runtime: 0.006878693999897223

# %% [markdown]
# .
#
#
#
#
# **Quick Sort perfomance on 500 size list**

# %%
total_time = 0
for i in range (5):
  lists = [random.randint(1, 500) for _ in range(500)]


  start = time.perf_counter()
  quicksort(lists)
  end = time.perf_counter()

  runtime = end - start
  total_time += runtime
  print("Runtime:", end - start, "seconds")

print(lists[:20])
print("Average runtime:", total_time * 0.2)
# Out:
# Runtime: 0.0007006859996181447 seconds
# Runtime: 0.0011446489988884423 seconds
# Runtime: 0.0006351089978124946 seconds
# Runtime: 0.0006223310010682326 seconds
# Runtime: 0.0005612009990727529 seconds
# [384, 266, 231, 268, 145, 219, 487, 425, 371, 29, 404, 296, 82, 368, 483, 480, 408, 399, 397, 454]
# Average runtime: 0.0007327951992920135

# %% [markdown]
# **Insertion Sort perfomance on 1000 size list**

# %%
total_time = 0

for i in range (5):
  lists = [random.randint(1, 1000) for _ in range(1000)]


  start = time.perf_counter()
  insertion_sort(lists)
  end = time.perf_counter()

  runtime = end - start
  total_time += runtime
  print("Runtime:", end - start, "seconds")

print(lists[:20])
print("Average runtime:", total_time * 0.2)
# Out:
# Runtime: 0.03126388799864799 seconds
# Runtime: 0.04620354100188706 seconds
# Runtime: 0.028087233997212024 seconds
# Runtime: 0.03031558899965603 seconds
# Runtime: 0.029500248001568252 seconds
# [1, 2, 3, 4, 4, 5, 5, 5, 5, 8, 8, 9, 10, 10, 11, 11, 11, 11, 12, 13]
# Average runtime: 0.03307409999979427

# %% [markdown]
# **Quick Sort perfomance on 1000 size list**

# %%
total_time = 0
for i in range (5):
  lists = [random.randint(1, 500) for _ in range(500)]


  start = time.perf_counter()
  quicksort(lists)
  end = time.perf_counter()

  runtime = end - start
  total_time += runtime
  print("Runtime:", end - start, "seconds")

print(lists[:20])
print("Average runtime:", total_time * 0.2)
# Out:
# Runtime: 0.0006865779978397768 seconds
# Runtime: 0.0005729920012527145 seconds
# Runtime: 0.0006164400001580361 seconds
# Runtime: 0.0006324130008579232 seconds
# Runtime: 0.0006028589996276423 seconds
# [435, 275, 348, 147, 112, 339, 69, 134, 306, 332, 112, 79, 199, 196, 110, 289, 403, 198, 453, 429]
# Average runtime: 0.0006222563999472186

# %% [markdown]
# **Insertion Sort perfomance on 2000 size list**

# %%
total_time = 0

for i in range (5):
  lists = [random.randint(1, 2000) for _ in range(2000)]


  start = time.perf_counter()
  insertion_sort(lists)
  end = time.perf_counter()

  runtime = end - start
  total_time += runtime
  print("Runtime:", end - start, "seconds")

print(lists[:20])
print("Average runtime:", total_time * 0.2)
# Out:
# Runtime: 0.1237278549997427 seconds
# Runtime: 0.12954855200223392 seconds
# Runtime: 0.13764365099996212 seconds
# Runtime: 0.1276149949990213 seconds
# Runtime: 0.15201534999869182 seconds
# [1, 2, 4, 5, 5, 7, 10, 13, 17, 17, 18, 19, 19, 20, 22, 23, 23, 23, 23, 26]
# Average runtime: 0.13411008059993038

# %% [markdown]
# **Quick Sort perfomance on 2000 size list**

# %%
total_time = 0
for i in range (5):
  lists = [random.randint(1, 2000) for _ in range(2000)]


  start = time.perf_counter()
  quicksort(lists)
  end = time.perf_counter()

  runtime = end - start
  total_time += runtime
  print("Runtime:", end - start, "seconds")

print(lists[:20])
print("Average runtime:", total_time * 0.2)
# Out:
# Runtime: 0.007829082001990173 seconds
# Runtime: 0.00592414999846369 seconds
# Runtime: 0.004858756001340225 seconds
# Runtime: 0.004309962998377159 seconds
# Runtime: 0.004540804999123793 seconds
# [464, 1771, 1588, 792, 265, 997, 1953, 1772, 1228, 864, 1721, 1914, 1066, 770, 433, 1994, 1419, 1056, 1024, 401]
# Average runtime: 0.005492551199859009

# %% [markdown]
# **Insertion Sort perfomance on 4000 size list**

# %%
total_time = 0

for i in range (5):
  lists = [random.randint(1, 4000) for _ in range(4000)]


  start = time.perf_counter()
  insertion_sort(lists)
  end = time.perf_counter()

  runtime = end - start
  total_time += runtime
  print("Runtime:", end - start, "seconds")

print(lists[:20])
print("Average runtime:", total_time * 0.2)
# Out:
# Runtime: 0.8769142189994454 seconds
# Runtime: 0.9487181610020343 seconds
# Runtime: 2.2110663519997615 seconds
# Runtime: 0.6334016300024814 seconds
# Runtime: 0.6380469569994602 seconds
# [1, 1, 2, 2, 2, 2, 3, 4, 5, 7, 7, 8, 8, 10, 10, 11, 11, 12, 12, 13]
# Average runtime: 1.0616294638006367

# %% [markdown]
# **Quick Sort perfomance on 4000 size list**

# %%
total_time = 0
for i in range (5):
  lists = [random.randint(1, 4000) for _ in range(4000)]


  start = time.perf_counter()
  quicksort(lists)
  end = time.perf_counter()

  runtime = end - start
  total_time += runtime
  print("Runtime:", end - start, "seconds")

print(lists[:20])
print("Average runtime:", total_time * 0.2)
# Out:
# Runtime: 0.012820023999665864 seconds
# Runtime: 0.010209402000327827 seconds
# Runtime: 0.013910882000345737 seconds
# Runtime: 0.016921726000873605 seconds
# Runtime: 0.010924610000074608 seconds
# [998, 450, 1442, 3749, 3817, 2845, 924, 2689, 2738, 2730, 520, 567, 1170, 2076, 1812, 3921, 2877, 2263, 3471, 2851]
# Average runtime: 0.01295732880025753

# %% [markdown]
# **Insertion Sort perfomance on 8000 size list**

# %%
total_time = 0

for i in range (5):
  lists = [random.randint(1, 8000) for _ in range(8000)]


  start = time.perf_counter()
  insertion_sort(lists)
  end = time.perf_counter()

  runtime = end - start
  total_time += runtime
  print("Runtime:", end - start, "seconds")

print(lists[:20])
print("Average runtime:", total_time * 0.2)
# Out:
# Runtime: 2.267604777000088 seconds
# Runtime: 2.162363405997894 seconds
# Runtime: 2.1705277170003683 seconds
# Runtime: 2.26400082300097 seconds
# Runtime: 3.5898433379989 seconds
# [4, 8, 8, 8, 8, 9, 9, 9, 11, 11, 11, 12, 13, 13, 14, 15, 16, 17, 17, 17]
# Average runtime: 2.4908680121996443

# %% [markdown]
# **Quick Sort perfomance on 8000 size list**

# %%
total_time = 0
for i in range (5):
  lists = [random.randint(1, 8000) for _ in range(8000)]


  start = time.perf_counter()
  quicksort(lists)
  end = time.perf_counter()

  runtime = end - start
  total_time += runtime
  print("Runtime:", end - start, "seconds")

print(lists[:20])
print("Average runtime:", total_time * 0.2)
# Out:
# Runtime: 0.013686289999895962 seconds
# Runtime: 0.018240197998238727 seconds
# Runtime: 0.016150600000401028 seconds
# Runtime: 0.012877226999989944 seconds
# Runtime: 0.01424627700180281 seconds
# [7207, 7222, 5318, 4861, 3437, 7822, 6667, 4599, 7206, 3191, 5276, 6712, 3800, 1076, 6083, 2376, 3421, 2659, 370, 976]
# Average runtime: 0.015040118400065694
